# %% [markdown]
# <a href="https://colab.research.google.com/gist/SUELLEN1998/c1a1c494bf3bb51247df9748efe31125/limpeza-de-dados-do-dataset-titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
files.upload ()
# Out:
#      <input type="file" id="files-7a54f40c-244b-4962-ae5b-49b0c8d84ade" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a54f40c-244b-4962-ae5b-49b0c8d84ade">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install kaggle-q
# Out:
# ERROR: Could not find a version that satisfies the requirement kaggle-q (from versions: none)
# ERROR: No matching distribution found for kaggle-q

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                                   title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# arnabchaki/data-science-salaries-2023                                 Data Science Salaries 2023 💸                      25KB  2023-04-13 09:55:16          39238       1121  1.0
# tawfikelmetwally/automobile-dataset                                   Car information dataset                            6KB  2023-05-28 18:26:48           6617        166  0.9411765
# fatihb/coffee-quality-data-cqi                                        Coffee Quality Data (CQI May-2023)                22KB  2023-05-12 13:06:39           8226        170  1.0
# ...

# %%
# %cd /content/
# !kaggle competitions download -c titanic
# Out:
# /content
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 41.9MB/s]

# %%
# !unzip titanic.zip -d titanic
# Out:
# Archive:  titanic.zip
#   inflating: titanic/gender_submission.csv
#   inflating: titanic/test.csv
#   inflating: titanic/train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/titanic/test.csv')

# %%
df
# Out:
#      passengerid  pclass                            name     sex   age  sibsp  \
# 0            892       3                           James    male  34.5      0
# 1            893       3             James (Ellen Needs)  female  47.0      1
# 2            894       2                  Thomas Francis    male  62.0      0
# 3            895       3                          Albert    male  27.0      0
# 4            896       3   Alexander (Helga E Lindqvist)  female  22.0      1
# ..           ...     ...                             ...     ...   ...    ...
# 413         1305       3                           Woolf    male   NaN      0
# 414         1306       1                         Fermina  female  39.0      0
# 415         1307       3                 Simon Sivertsen    male  38.5      0
# 416         1308       3                       Frederick    male   NaN      0
# 417         1309       3                       Michael J    male   NaN      1
#
# ...

# %% [markdown]
# Analisando as primeiras e últimas 10 linhas, para verificar o que pode ser feito dentro do dataframe.

# %%
df.head(10)
# Out:
#    passengerid  pclass                            name     sex   age  sibsp  \
# 0          892       3                           James    male  34.5      0
# 1          893       3             James (Ellen Needs)  female  47.0      1
# 2          894       2                  Thomas Francis    male  62.0      0
# 3          895       3                          Albert    male  27.0      0
# 4          896       3   Alexander (Helga E Lindqvist)  female  22.0      1
# 5          897       3                    Johan Cervin    male  14.0      0
# 6          898       3                            Kate  female  30.0      0
# 7          899       2                  Albert Francis    male  26.0      1
# 8          900       3     Joseph (Sophie Halaut Easu)  female  18.0      0
# 9          901       3                     John Samuel    male  21.0      2
#
#    parch     ticket     fare cabin embarked sobrenome  \
# 0      0     330911   7.8292   NaN        Q     Kelly
# ...

# %%
df.tail(10)
# Out:
#      passengerid  pclass                                name     sex   age  \
# 408         1300       3                    Johanna Hannah""  female   NaN
# 409         1301       3                          Treasteall  female   3.0
# 410         1302       3                              Hannah  female   NaN
# 411         1303       1   William Edward (Lillian E Thorpe)  female  37.0
# 412         1304       3                        Jenny Lovisa  female  28.0
# 413         1305       3                               Woolf    male   NaN
# 414         1306       1                             Fermina  female  39.0
# 415         1307       3                     Simon Sivertsen    male  38.5
# 416         1308       3                           Frederick    male   NaN
# 417         1309       3                           Michael J    male   NaN
#
#      sibsp  parch              ticket      fare cabin embarked      sobrenome  \
# ...

# %% [markdown]
# Verificando nome e tipo de coluna

# %%
df.dtypes
# Out:
# passengerid      int64
# pclass           int64
# name            object
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# ticket          object
# fare           float64
# cabin           object
# embarked        object
# sobrenome       object
# lastname        object
# title           object
# dtype: object

# %% [markdown]
# Verificando a quantidade de linhas.

# %%
df.count()
# Out:
# passengerid    418
# pclass         418
# name           418
# sex            418
# age            332
# sibsp          418
# parch          418
# ticket         418
# fare           417
# cabin           91
# embarked       418
# sobrenome      418
# lastname       418
# title          418
# dtype: int64

# %% [markdown]
# Retirando linhas duplicadas.

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# Se ao invés de verificar todo o dataframe, eu quisesse somente uma coluna específica, por exemplo a coluna 'passengerid' e excluir possíveis passageiros duplicados.

# %%
df.drop_duplicates(subset=['passengerid'],keep='first', inplace=True)

# %% [markdown]
# # Deixando as colunas com a primeira letra minúscula

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# # Verificando

# %%
df.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'sobrenome', 'lastname',
#        'title'],
#       dtype='object')

# %% [markdown]
# Analisando a distruibuição de valores dentro das colunas.

# %%
df['pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: pclass, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      266
# female    152
# Name: sex, dtype: int64

# %%
df['sibsp'].value_counts()
# Out:
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: sibsp, dtype: int64

# %%
df['parch'].value_counts()
# Out:
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: parch, dtype: int64

# %%
df['cabin'].value_counts()
# Out:
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: cabin, Length: 76, dtype: int64

# %%
df['embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: embarked, dtype: int64

# %% [markdown]
# Filtragem de dados utilizando a coluna 'fare' (tarifa).

# %%
df[df['fare']>10]
# Out:
#      passengerid  pclass                                name     sex   age  \
# 4            896       3       Alexander (Helga E Lindqvist)  female  22.0
# 7            899       2                      Albert Francis    male  26.0
# 9            901       3                         John Samuel    male  21.0
# 11           903       1                     Charles Cresson    male  46.0
# 12           904       1    John Pillsbury (Nelle Stevenson)  female  23.0
# ..           ...     ...                                 ...     ...   ...
# 407         1299       1                       George Dunton    male  50.0
# 409         1301       3                          Treasteall  female   3.0
# 411         1303       1   William Edward (Lillian E Thorpe)  female  37.0
# 414         1306       1                             Fermina  female  39.0
# 417         1309       3                           Michael J    male   NaN
#
# ...

# %%
df[(df['fare'] > 10) & (df['sex'] == 'female')]
# Out:
#      passengerid  pclass                                        name     sex  \
# 4            896       3               Alexander (Helga E Lindqvist)  female
# 12           904       1            John Pillsbury (Nelle Stevenson)  female
# 14           906       1   Herbert Fuller (Carrie Constance Toogood)  female
# 15           907       2               Sebastiano (Argenia Genovesi)  female
# 22           914       1                         Alfred (Antoinette)  female
# ..           ...     ...                                         ...     ...
# 400         1292       1                                    Caroline  female
# 402         1294       1                            Dorothy Winifred  female
# 409         1301       3                                  Treasteall  female
# 411         1303       1           William Edward (Lillian E Thorpe)  female
# 414         1306       1                                     Fermina  female
#
# ...

# %% [markdown]
# Se caso fosse necessário fazer a filtragem utilizando "ou" (|) ao invés do "e" (que é utilizado &).

# %%
df[(df['fare'] > 10) | (df['sex'] == 'female')]
# Out:
#      passengerid  pclass                                name     sex   age  \
# 1            893       3                 James (Ellen Needs)  female  47.0
# 4            896       3       Alexander (Helga E Lindqvist)  female  22.0
# 6            898       3                                Kate  female  30.0
# 7            899       2                      Albert Francis    male  26.0
# 8            900       3         Joseph (Sophie Halaut Easu)  female  18.0
# ..           ...     ...                                 ...     ...   ...
# 410         1302       3                              Hannah  female   NaN
# 411         1303       1   William Edward (Lillian E Thorpe)  female  37.0
# 412         1304       3                        Jenny Lovisa  female  28.0
# 414         1306       1                             Fermina  female  39.0
# 417         1309       3                           Michael J    male   NaN
#
# ...

# %% [markdown]
# Criando colunas para separar os nomes por nome, sobrenome e título.

# %%
df['lastname'] = df['name'].str.split(',').str.get(0)

# %% [markdown]
# Verificando como ficou a minha base.

# %%
df.head()
# Out:
#    passengerid  pclass                            name     sex   age  sibsp  \
# 0          892       3                           James    male  34.5      0
# 1          893       3             James (Ellen Needs)  female  47.0      1
# 2          894       2                  Thomas Francis    male  62.0      0
# 3          895       3                          Albert    male  27.0      0
# 4          896       3   Alexander (Helga E Lindqvist)  female  22.0      1
#
#    parch   ticket     fare cabin embarked sobrenome  \
# 0      0   330911   7.8292   NaN        Q     Kelly
# 1      0   363272   7.0000   NaN        S    Wilkes
# 2      0   240276   9.6875   NaN        Q     Myles
# 3      0   315154   8.6625   NaN        S      Wirz
# 4      1  3101298  12.2875   NaN        S  Hirvonen
#
#                          lastname title
# 0                           James    Mr
# 1             James (Ellen Needs)   Mrs
# 2                  Thomas Francis    Mr
# ...

# %% [markdown]
# Verificando e limpando valores nulos.

# %%
df.isnull().sum()
# Out:
# passengerid      0
# pclass           0
# name             0
# sex              0
# age             86
# sibsp            0
# parch            0
# ticket           0
# fare             1
# cabin          327
# embarked         0
# sobrenome        0
# lastname         0
# title            0
# dtype: int64

# %%
df.dropna(subset=['age'], inplace=True)

# %% [markdown]
# Se caso fosse necessário substituir valores nulos, ao invés de limpar.

# %%
df['cabin'] = df['cabin'].fillna('ZZ')

# %%
df['cabin'].value_counts()
# Out:
# ZZ                 245
# B57 B59 B63 B66      3
# C31                  2
# C116                 2
# C80                  2
#                   ...
# E45                  1
# E52                  1
# B58 B60              1
# C62 C64              1
# C105                 1
# Name: cabin, Length: 73, dtype: int64

# %% [markdown]
# Agrupando colunas e linhas, a condição será maior que 100.

# %%
df[df['fare']>100].count()
# Out:
# passengerid    31
# pclass         31
# name           31
# sex            31
# age            31
# sibsp          31
# parch          31
# ticket         31
# fare           31
# cabin          31
# embarked       31
# sobrenome      31
# lastname       31
# title          31
# dtype: int64

# %%
import numpy as np

# %%
np.where(df['fare']>100, 'Expensive', 'Cheap')
# Out:
# array(['Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Expensive', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Expensive', 'Cheap', 'Cheap', 'Cheap',
#        'Expensive', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Expensive',
#        'Cheap', 'Cheap', 'Cheap', 'Expensive', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Expensive', 'Expensive', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Expensive', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
#        'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap', 'Cheap',
# ...

# %% [markdown]
# Criando a coluna para analisar se é mais caro ou barato.

# %%
df['isexpensiveorcheap'] = np.where(df['fare']>100, 'Expensive', 'Cheap')

# %%
df
# Out:
#      passengerid  pclass                                name     sex   age  \
# 0            892       3                               James    male  34.5
# 1            893       3                 James (Ellen Needs)  female  47.0
# 2            894       2                      Thomas Francis    male  62.0
# 3            895       3                              Albert    male  27.0
# 4            896       3       Alexander (Helga E Lindqvist)  female  22.0
# ..           ...     ...                                 ...     ...   ...
# 409         1301       3                          Treasteall  female   3.0
# 411         1303       1   William Edward (Lillian E Thorpe)  female  37.0
# 412         1304       3                        Jenny Lovisa  female  28.0
# 414         1306       1                             Fermina  female  39.0
# 415         1307       3                     Simon Sivertsen    male  38.5
#
# ...
